# %%
import numpy as np
import pandas as pd
#%pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Data dimensionality, distance-based classifiers
# Excercise with mnist digit dataset. Lets first load the data and take a peek:

# %%
X_train = pd.read_csv('./data/train_in.csv',header=None)
Y_train = pd.read_csv('./data/train_out.csv',header=None)
df_train = X_train.copy()
df_train['label']=Y_train

# %%
def show_number(nr,data):    
    X=np.array(data)
    X=np.reshape(X[nr,:],(16,16))
    imgplot = plt.imshow(X)
    plt.axis('off')
    
    plt.title('Example digit')
    plt.show()
show_number(0,X_train)
print('Figure 1: Exapmle of one element in the dataset')
# Out:
# Figure 1: Exapmle of one element in the dataset

# %% [markdown]
# How big is the difference between numbers?

# %%
def get_image(nr,data):
    if 'label' in data.columns:
        data=np.array(data.drop('label',axis=1))
    else:
        data=data.values
    return np.reshape(data[nr,:],(16,16))

def display_multiple_img(images, rows = 3, cols=3):
    figure, ax = plt.subplots(nrows=rows,ncols=cols,figsize=(10,10))
    for ind,title in enumerate(images):
        ax.ravel()[ind].imshow(images[title])
        ax.ravel()[ind].set_axis_off()
    plt.tight_layout()
    plt.show()

def display_digits(digit,data,rows,cols):
    total_images = rows*cols
    index=data.loc[data.label==digit].index[:total_images]
    images = {'Image'+str(i):get_image(i,data) for i in index}
    display_multiple_img(images, rows, cols)

    
for i in range(10):
    display_digits(i,df_train,rows=1,cols=9)
print('Figure 2: first 9 appearances of each digit')
# Out:
# Figure 2: first 9 appearances of each digit

# %% [markdown]
# For each digit d in range(10) calculate the 'centre': $c_{d}$ as the mean of allcoordinates of vectors constructin $C_{d}$.

# %%
c_ds=df_train.groupby('label').mean()

images = {'Image'+str(i):get_image(i,c_ds) for i in range(10)}
display_multiple_img(images, 2,5)
print('Figure 3: The average digits')
# Out:
# Figure 3: The average digits

# %% [markdown]
# Next, calculate the distances between the centers of the 10 clouds, $dist_{ij} = dist(c_{i}; c_{j} )$, for
# $i,j = 0,1,...9$.

# %%
from itertools import product
dist_ij=np.zeros((10,10))
for i,j in product(range(10),range(10)):
    if j>=i:
        dist_ij[i,j]=np.linalg.norm(c_ds.iloc[i].values-c_ds.iloc[j].values)
imgplot = plt.imshow(dist_ij)
plt.title(label='distance between each of the digits')
plt.xticks(range(10))
plt.yticks(range(10))
plt.show()
print('Figure 4: Distances of averages')
# Out:
# Figure 4: Distances of averages

# %% [markdown]
# #### Question
# Given all these distances, try to say something about the expected accuracy of your
# classifier. What pairs of digits seem to be most difficult to separate?
# #### Answer
# Looking at the graph i would suspect its hard to distinguish between 4 and 9, 7 and 9, 8 and 9, 3 and 5.

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, LocallyLinearEmbedding
from matplotlib import cm

# %%
#Dimension reduction
pca = PCA(n_components=2)
lle = LocallyLinearEmbedding(n_components=2)
tsne = TSNE(n_components=2)

methods={'pca':pca,'lle':lle,'tsne':tsne}
dfs=dict()
for key in methods:
    X=methods[key].fit_transform(X_train)
    df=pd.DataFrame(X)
    df['label']=Y_train
    dfs[key]=df

# %%
def scatter_plot(c_ds,title):
    plt.scatter(c_ds.values[:,0],c_ds.values[:,1],c=Y_train)
    plt.title(title)

# %%
def scatter_plot(c_ds,title):
    fig, ax = plt.subplots()
    colors={0:'tab:red',1:'tab:blue',2:'tab:orange',3:'tab:green',4:'tab:purple',5:'tab:brown',6:'tab:pink',7:'tab:gray',8:'tab:olive',9:'tab:cyan'}
    for key in colors:
        x=c_ds.loc[c_ds.label==key].values[:,0]
        y=c_ds.loc[c_ds.label==key].values[:,1]
        ax.scatter(x,y, c=colors[key], label=key,
                   alpha=0.3, edgecolors='none')
    
    
    average=c_ds.groupby('label').mean()
    ax.scatter(average.values[:,0],average.values[:,1])
    for i in range(10):
        label = f"{c_ds.index[i]}"
        plt.annotate(label, # this is the text
             (average.values[i,0],average.values[i,1]), # this is the point to label
             textcoords="offset points", # how to position the text
             xytext=(0,10), # distance from text to points (x,y)
             ha='center') # horizontal alignment can be left, right or   
    ax.legend()
    plt.title(title)
    plt.show()

# %%
scatter_plot(dfs['pca'],'PCA')

# %%
scatter_plot(dfs['lle'],'LocallyLinearEmbedding')

# %%
scatter_plot(dfs['tsne'],'t-SNE')

# %%
class DistanceBasedClassifier:

    def __init__(self):
        self.c_ds=None
        
    def fit(self,X,Y):
        df_train = X.copy()
        df_train['label']=Y
        self.c_ds=df_train.groupby('label').mean()
    
    def predict(self,X):
        probability_matrix=pd.DataFrame()
        for i in range(10):
            df=X-self.c_ds.iloc[i]
            probability_matrix[i]=np.sqrt(np.multiply(df.abs(),df.abs()).sum(axis=1))
        predictions=np.argmin(probability_matrix.values,axis=1)
        #self.probabilities=1-(np.min(dbc.probability_matrix,axis=1)/np.sum(dbc.probability_matrix,axis=1))
        return predictions
    
    def evaluate(self,X,Y):
        probability_matrix=pd.DataFrame()
        for i in range(10):
            df=X-self.c_ds.iloc[i]
            probability_matrix[i]=np.sqrt(np.multiply(df.abs(),df.abs()).sum(axis=1))
        predictions=np.argmin(probability_matrix.values,axis=1)
        score=(len(Y)-np.sum(predictions-Y.values.T))/len(Y)
        return score

# %%
dbc=DistanceBasedClassifier()
dbc.fit(X_train,Y_train)

# %%
prediction=dbc.predict(X_train)

# %%
dbc.evaluate(X_train,Y_train)
# Out:
# 0.8980667838312829

# %%
X_test = pd.read_csv('./data/test_in.csv',header=None)
Y_test = pd.read_csv('./data/test_out.csv',header=None)

# %%
prediction_test=dbc.predict(X_test)

# %%
dbc.evaluate(X_test,Y_test)
# Out:
# 0.833

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(X_train, Y_train.values.ravel())
# Out:
# KNeighborsClassifier()

# %%
Y_pred=neigh.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       224
#            1       0.91      0.98      0.94       121
#            2       0.93      0.83      0.88       101
#            3       0.82      0.89      0.85        79
#            4       0.94      0.92      0.93        86
#            5       0.95      0.64      0.76        55
#            6       0.94      0.94      0.94        90
#            7       0.86      0.88      0.87        64
#            8       0.95      0.86      0.90        92
#            9       0.88      0.93      0.91        88
#
#     accuracy                           0.91      1000
#    macro avg       0.91      0.88      0.89      1000
# weighted avg       0.91      0.91      0.91      1000

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
conf_matrix=confusion_matrix(Y_test,Y_pred)#confusion matrix distance based classifier
def plot_conf_matrix(conf_matrix):
    fig, ax = plt.subplots(figsize=(10,10))
    ax.matshow(conf_matrix, aspect='auto')
    ax.set(title='Confusion Matrix', xticks=range(10), 
           yticks=range(10))
    for (i, j), val in np.ndenumerate(conf_matrix):
        ax.annotate('{:0.2f}'.format(val), (j,i), ha='center', va='center',color='white')
plot_conf_matrix(conf_matrix)

# %%
X_train = pd.read_csv('./data/train_in.csv',header=None)
Y_train = pd.read_csv('./data/train_out.csv',header=None)
X_test = pd.read_csv('./data/test_in.csv',header=None)
Y_test = pd.read_csv('./data/test_out.csv',header=None)
df_train = X_train.copy()
df_train['label']=Y_train
T_train=X_train.copy()
T_train['bias']=1
T_test=X_test.copy()
T_test['bias']=1

# %% [markdown]
# T_train=X_train.copy()
# T_test=X_test.copy()
# T_train['bias']=1 #trainset
# T_test['bias']=1 #testset
# print(T_train.shape,T_test.shape)

# %%
W=np.random.random((257,10))
output=np.argmax(np.dot(T_train,W),axis=1)
prediction=np.argmax(np.dot(T_train,W),axis=1)

# %% [markdown]
# $\Delta W = \sum_{mis qualified} $ <br>
# for misqualified point: Y_label,Y_prediction <br>
# if elementwise(W[:,Y_label] < W[:,Y_precition]): <br>
#     W[:,Y_precition] - T_train[?]<br>
#     W[:,Y_label] + T_train[?]<br>

# %%
for i,(pred,label) in enumerate(zip(prediction,Y_train.values[:,0])):
    if pred != label:
        W[:,pred]-=T_train.iloc[i]*W[:,pred]>W[:,label]
        W[:,label]+=T_train.iloc[i]*W[:,pred]<W[:,label]

# %%
prediction=np.argmax(np.dot(T_train,W),axis=1)

# %%
sum(prediction.T==Y_train.values[:,0])
# Out:
# 122

# %%
W=np.random.random((257,10))
counter=0
total=len(Y_train)
times_right=0
while counter<30:
    output=np.argmax(np.dot(T_train,W),axis=1)
    prediction=np.argmax(np.dot(T_train,W),axis=1)
    if times_right == total:
        break
    for i,(pred,label) in enumerate(zip(prediction,Y_train.values[:,0])):
        if pred != label:
            W[:,pred]-=T_train.iloc[i]*(W[:,pred]>W[:,label])
            W[:,label]+=T_train.iloc[i]*(W[:,pred]>W[:,label])
    times_right=sum(prediction.T==Y_train.values[:,0])
    print(f'itaration {counter}, times right: {times_right},percentage: {times_right/total}')    
    counter+=1
# Out:
# itaration 0, times right: 66,percentage: 0.03866432337434095
# itaration 1, times right: 509,percentage: 0.29818394844756885
# itaration 2, times right: 803,percentage: 0.47041593438781487
# itaration 3, times right: 826,percentage: 0.4838898652606913
# itaration 4, times right: 842,percentage: 0.4932630345635618
# itaration 5, times right: 1075,percentage: 0.629759812536614
# itaration 6, times right: 1268,percentage: 0.7428236672524897
# itaration 7, times right: 1345,percentage: 0.7879320445225542
# itaration 8, times right: 1395,percentage: 0.8172231985940246
# itaration 9, times right: 1459,percentage: 0.8547158758055068
# itaration 10, times right: 1476,percentage: 0.8646748681898067
# itaration 11, times right: 1498,percentage: 0.8775629759812537
# itaration 12, times right: 1512,percentage: 0.8857644991212654
# itaration 13, times right: 1514,percentage: 0.8869361452841242
# itaration 14, times right: 1522,percentage: 0.8916227299355595
# itaration 15, times right: 1523,percentage: 0.8922085530169889
# itaration 16, times right: 1526,percentage: 0.8939660222612771
# itaration 17, times right: 1522,percentage: 0.8916227299355595
# itaration 18, times right: 1532,percentage: 0.8974809607498535
# itaration 19, times right: 1533,percentage: 0.8980667838312829
# itaration 20, times right: 1534,percentage: 0.8986526069127123
# itaration 21, times right: 1543,percentage: 0.9039250146455771
# itaration 22, times right: 1540,percentage: 0.9021675454012889
# itaration 23, times right: 1542,percentage: 0.9033391915641477
# itaration 24, times right: 1547,percentage: 0.9062683069712947
# itaration 25, times right: 1547,percentage: 0.9062683069712947
# itaration 26, times right: 1550,percentage: 0.9080257762155829
# itaration 27, times right: 1551,percentage: 0.9086115992970123
# itaration 28, times right: 1556,percentage: 0.9115407147041593
# itaration 29, times right: 1555,percentage: 0.9109548916227299

# %% [markdown]
# ### Task 3

# %%
import math

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def xor_net(x1, x2,weights):
    '''
    input 2-d
    hidden layer1 2 nodes
    hidden layer2 1 node, activation: sigmoid
    '''
    W1=np.reshape(weights[:4],(2,2))
    b1=weights[4:6]
    W2=np.reshape(weights[6:8],(2,1))
    b2=weights[-1]
    
    #input layer
    X0=np.array([x1,x2])
    # hidden layer1
    X1=sigmoid(np.dot(X0,W1)+b1)
    #hidden layer2
    Y=sigmoid(np.dot(X1,W2)+b2)
    return Y

# %%
weights=np.random.random(9)
x1=2
x2=3
xor_net(x1,x2,weights)
# Out:
# array([0.85368651])

# %%
def xor_net_2(x1, x2,weights):
    (w13,w14,w23,w24,bias3,bias4,w3y,w4y,biasy)=weights 
    Y=sigmoid(biasy+w3y*sigmoid(bias3+w13*x1+w23*x2)+w4y*sigmoid(bias4+w14*x1+w24*x2))
    return Y

# %% [markdown]
# weights = (biasy,bias3,bias4,w13,w14,w23,w24,w3y,w4y)

# %%
xor_net_2(x1, x2,weights)
# Out:
# 0.8536865144560932

# %%
#define data with corresponding targets
x = {'x1':[0,0,1,1],'x2':[0,1,0,1]}
xdf = pd.DataFrame(data=x)
y = {'target':[0,1,1,0]}
ydf = pd.DataFrame(data=y)
df=xdf.copy()
df['target']=y['target']

# %%
def mse(weights_initial,X_data,Y_data):
    sumerror=0
    for i in range(len(x['x1'])):
        errorsq = np.square(xor_net(X_data.iloc[i][0],X_data.iloc[i][1],weights_initial)
        -Y_data.iloc[i][0])
        sumerror+=errorsq
    mserror=sumerror/len(X_data['x1'])
    return mserror

# %%
def grdmse(weights_initial,X_data,Y_data,delta):
    gradient=np.zeros(9)
    weights_delta=weights_initial
    for i in range(len(weights_initial)):
        weights_delta[i]+=delta
        gradient_i=(mse(weights_delta,X_data,Y_data)-mse(weights_initial,X_data,Y_data))/delta
        #op een of andere manier is weights_delta==weights_initial true hier?
        #hierdoor gradient_i=0
        weights_delta[i]-=delta
        gradient[i]+=gradient_i
    return gradient

# %%
grdmse(weights,xdf,ydf,0.1)
# Out:
# [0.43936587]
# [ True  True  True  True  True  True  True  True  True]
# [0.43932924]
# [ True  True  True  True  True  True  True  True  True]
# [0.43935765]
# [ True  True  True  True  True  True  True  True  True]
# [0.43932536]
# [ True  True  True  True  True  True  True  True  True]
# [0.44011589]
# [ True  True  True  True  True  True  True  True  True]
# [0.43984479]
# [ True  True  True  True  True  True  True  True  True]
# [0.44350336]
# [ True  True  True  True  True  True  True  True  True]
# [0.44361553]
# [ True  True  True  True  True  True  True  True  True]
# [0.44437373]
# [ True  True  True  True  True  True  True  True  True]
# array([0., 0., 0., 0., 0., 0., 0., 0., 0.])
